# %% [markdown]
# <a href="https://colab.research.google.com/github/paolopolinar/-Kamia-Polinar-grade8-library-Repo/blob/main/Kamia_Polinar_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
# Open the JSON file
with open("/content/books.json") as f:
 students = json.load(f)
# Display the JSON content
print(students)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebase_key.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://kamiapolinar-grade8-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/"
})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import json
with open("/content/books.json", "r") as file:
 data = json.load(file)
print("JSON file loaded")
ref = db.reference("books")
for book in data["books"]:
 ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for book_id, info in books_data.items():
 print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for book_id, info in books_data.items():
 print(info["title"], info["details"])
# Out:
# Introduction to Python {'available': 3, 'copies': 5}
# Data Structures Basics {'available': 2, 'copies': 4}
# Web Development Essentials {'available': 6, 'copies': 6}

# %%
# Fetch data from Firebase
books_data = ref.get()  # returns a dictionary with keys "2001", "2002", ...

# %%
for key, book in books_data.items():
 title = book["title"]
 copies = book["details"]["copies"]
 available = book["details"]["available"]
 print(f"Title: {title}")
 print(f"Copies: {copies}")
 print(f"Available: {available}")
# Out:
# Title: Introduction to Python
# Copies: 5
# Available: 3
# Title: Data Structures Basics
# Copies: 4
# Available: 2
# Title: Web Development Essentials
# Copies: 6
# Available: 6

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for book_id, info in books_data.items():
 print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for book_id, info in books_data.items():
 print(info["title"], info["details"]["available"])
# Out:
# Introduction to Python 3
# Data Structures Basics 2
# Web Development Essentials 6

# %%
total_books = 0

for book_id, info in books_data.items():
 total_books += info["details"]["copies"]

print("Total number of books in library:", total_books)
# Out:
# Total number of books in library: 15
